# %% [markdown]
# # 00 Setup Check — R
#
# Confirm the R kernel works inside Jupyter Notebook.

# %%
R.version.string

# %%
# Run only if needed:
# install.packages('tidyverse')
library(tidyverse)
print('tidyverse loaded successfully')

# %% [markdown]
# ## Reflection
#
# - Does the R kernel work?
# - Does `library(tidyverse)` load successfully?
