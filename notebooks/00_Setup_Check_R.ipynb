# %% [markdown]
# # 00 Setup Check - R
#
# ## Biochemistry question
#
# Which R tools are needed to load a small synthetic Biochemistry dataset, calculate basic statistics, and make a ggplot figure?

# %%
R.version.string

# %%
# Run only if needed:
# install.packages('tidyverse')
library(tidyverse)
print('tidyverse loaded successfully')

# %% [markdown]
# ## Interpretation Questions
#
# - Does the R kernel work inside Jupyter?
# - Does `library(tidyverse)` load successfully?
# - What would you check next if the R kernel does not appear?
#
# ## Limitations
#
# - This setup check does not analyze a real experiment.
# - R package availability can differ by computer, so setup issues may need local troubleshooting.
