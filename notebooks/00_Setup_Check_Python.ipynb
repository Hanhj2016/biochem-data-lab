# %% [markdown]
# # 00 Setup Check - Python
#
# ## Biochemistry question
#
# Which Python tools are needed to load a small synthetic Biochemistry dataset, calculate basic statistics, and make an interactive figure?

# %%
import plotly.io as pio
pio.renderers.default = "iframe"

# %%
import sys
print(sys.version)
# Out:
# 3.11.15 (main, Mar 11 2026, 17:20:07) [GCC 14.3.0]

# %%
import pandas as pd
import numpy as np
import scipy
import statsmodels
import plotly.express as px

print('pandas:', pd.__version__)
print('numpy:', np.__version__)
print('scipy:', scipy.__version__)
print('statsmodels:', statsmodels.__version__)
print('Plotly imported successfully')
# Out:
# pandas: 3.0.3
# numpy: 2.4.6
# scipy: 1.17.1
# statsmodels: 0.14.6
# Plotly imported successfully

# %% [markdown]
# ## Interpretation Questions
#
# - Did the core Python packages import successfully?
# - Which package seems most connected to statistics?
# - Which package seems useful for interactive charts?
#
# ## Limitations
#
# - This setup check does not analyze a real experiment.
# - Package imports only confirm that the tools are available; they do not confirm that every future notebook cell will run on every computer.
