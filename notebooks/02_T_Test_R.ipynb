# %% [markdown]
# # 02 Control vs Treatment t-test — R
#
# Same use case as Python.

# %%
library(tidyverse)

df <- read_csv('../data/enzyme_activity_sample.csv')
t.test(enzyme_activity ~ group, data = df)

# %% [markdown]
# ## Compare with Python
#
# - R's `t.test()` is compact. Is that easier?
# - Which version feels more transparent?
